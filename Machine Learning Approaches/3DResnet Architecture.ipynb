# %%
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Conv3D, MaxPool3D , Flatten, Dense
from keras.layers import Dropout, Input, BatchNormalization
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from sklearn.metrics import confusion_matrix
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import TimeDistributed
import matplotlib.pyplot as plt
import glob
import shutil
from pathlib import Path

# %%
path = r"E:\Graduation Project/new"
awake_path_dst = r"/content/drive/MyDrive/Dataset/new/train/awake"
drowsy_path_dst = "/content/drive/MyDrive/Dataset/new/train/drowsy"
count = 0

for path in Path(path).rglob('*.avi'):
    if(path.name == "nonsleepyCombination.avi"):
        print('here')
        new_vid_name = path.name + '_' + str(count) +'.avi'
        shutil.copyfile(path, os.path.join(awake_path_dst, new_vid_name))
    else: 
        new_vid_name = path.name + '_' + str(count) +'.avi'
        shutil.copyfile(path, os.path.join(drowsy_path_dst, new_vid_name))
    count += 1
# Out:
# here
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4116/3948349952.py in <module>
#       8         print('here')
#       9         new_vid_name = path.name + '_' + str(count) +'.avi'
# ---> 10         shutil.copyfile(path, os.path.join(awake_path_dst, new_vid_name))
#      11     else:
#      12         new_vid_name = path.name + '_' + str(count) +'.avi'
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     263     else:
#     264         try:
# --> 265             with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     266                 # macOS
#     267                 if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\Graduation Project/new/awake\\nonsleepyCombination.avi_0.avi'

# %%
data_dir =r"E:\Graduation Project\Project Data\new\train"
img_height , img_width = 64,64
seq_len = 15
 
classes = ['awake', 'drowsy']

# %%
def frames_extraction(video_path):
    frames_list = []
    frames = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 0
    success = True
    while success: 
         
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (img_height, img_width))
            norm_img = np.zeros((800,800))
            final_img = cv2.normalize(image,  norm_img, 0, 255, cv2.NORM_MINMAX)
            frames_list.append(final_img)
            count += 1
        else:
            print("Defected frame")
            count+=1
            break
        if(count == seq_len):
            if(len(frames_list) != 15):
                frames_list = []
                count = 1
                continue
            frames.append(frames_list)
            frames_list = []
            count = 1
   
    return frames

# %%
def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
            frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
            # print(len(frames))
            for f in frames:       
                if len(f) == seq_len:
                    X.append(f)
                
                    y = [0]*len(classes)
                    y[classes.index(c)] = 1
                    Y.append(y)
     
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

X, Y = create_data(data_dir)
# l = frames_extraction('new/train/awake/nonsleepyCombination.avi_176.avi')
# for ll in l:
    # print(len(ll))
print(X.shape, Y.shape)
# Out:
# awake
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# drowsy
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# Defected frame
# (356, 15, 64, 64, 3) (356, 2)

# %%
input_layer = Input((15 ,64 , 64, 3))
  
x_train ,x_test , y_train , y_test = train_test_split(X , Y , test_size=.25 ,shuffle = True, random_state = 0 )
#x_test1, x_valid, y_test1, y_valid = train_test_split(x_test, y_test, test_size=0.30)

# %%
def creating_model(input_layer):
## convolutional layers
    conv_layer1 = Conv3D(filters=64, kernel_size=(3, 3, 3) , padding = 'same')(input_layer)
    pooling_layer1 = MaxPool3D(pool_size=(2, 2, 2), padding = 'same')(conv_layer1)
    pooling_layer1 = BatchNormalization()(pooling_layer1)

    conv_layer2 = Conv3D(filters=64, kernel_size=(3, 3, 3) , padding = 'same')(pooling_layer1)
    pooling_layer2 = MaxPool3D(pool_size=(2, 2, 2))(conv_layer2)
    pooling_layer2 = BatchNormalization()(pooling_layer2)
## add max pooling to obtain the most imformatic features
    
    conv_layer3 = Conv3D(filters=128, kernel_size=(3, 3, 3),padding='same' )(pooling_layer2)
    conv_layer4 = Conv3D(filters=128, kernel_size=(3, 3, 3),padding='same')(conv_layer3)
    pooling_layer3 = MaxPool3D(pool_size =(2,2,2),padding='same')(conv_layer4)
    pooling_layer3 = BatchNormalization()(pooling_layer3)

    conv_layer5 = Conv3D(filters=256, kernel_size=(6, 1, 1) ,padding='same')(pooling_layer3)
    conv_layer6 = Conv3D(filters=512, kernel_size=(1,1,1), padding='same')(conv_layer5)
    pooling_layer4 = MaxPool3D(pool_size=(2,2,2), padding='same' )(conv_layer6)
    pooling_layer4 = BatchNormalization()(pooling_layer4)
## perform batch normalization on the convolution outputs before feeding it to MLP architecture
    
    flatten_layer = Flatten()(pooling_layer4)
    dense_layer1 = Dense(units = 128 , activation = 'relu')(flatten_layer)
    
    
    #dense_layer1 = Dropout(0.2)(dense_layer1)
    #dense_layer2 = Dense(units=32, activation='relu')(dense_layer1)
    #dense_layer2 = Dropout(0.2)(dense_layer2)
    #dense_layer3 = Dense(units  = 16 , activation=('relu'))(dense_layer2)
    #dense_layer3 = Dropout(.2)(dense_layer3)
    #dense_layer4 = Dense(units = 8 , activation = 'relu')(dense_layer3)
    #dense_layer4 = Dropout(.2)(dense_layer4)
    #dense_layer5 = Dense(units = 4 , activation = 'relu')(dense_layer4)
    #dense_layer5 = Dropout(.2)(dense_layer5)
    output_layer = Dense(units=2, activation='sigmoid')(dense_layer1)

## define the model with input layer and output layer
    model = Model(inputs=input_layer, outputs=output_layer)
    return model

# %%
# !pip install git+https://github.com/JihongJu/keras-resnet3d.git
from resnet3d import Resnet3DBuilder
#from lib.model_ResNet3D import Resnet3DBuilder
model = Resnet3DBuilder.build_resnet_50((15, 64, 64, 3), 2)

#model = creating_model(input_layer)
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.00001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

history = model.fit(x=x_train , y= y_train, batch_size=15, epochs=18 , validation_split = .25)


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
#loss, accuracy = model.evaluate((x_test,y_test))
print(sum(acc)/18)
print(sum(val_acc)/18)
print(sum(loss)/18)
print(sum(val_loss)/18)
# Out:
# Collecting git+https://github.com/JihongJu/keras-resnet3d.git
#   Cloning https://github.com/JihongJu/keras-resnet3d.git to c:\users\mosta\appdata\local\temp\pip-req-build-aih5i8zr
#   Resolved https://github.com/JihongJu/keras-resnet3d.git to commit 6e3a5c8b50f34d5e62193efa3fad88517c012707
# Requirement already satisfied: keras>=2.0.0 in c:\users\mosta\anaconda3\lib\site-packages (from keras-resnet3d==0.0.1) (2.7.0)
#   Running command git clone -q https://github.com/JihongJu/keras-resnet3d.git 'C:\Users\mosta\AppData\Local\Temp\pip-req-build-aih5i8zr'
#   Running command git submodule update --init --recursive -q
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 15, 64, 64,  0           []
#                                  3)]
#
#  conv3d_106 (Conv3D)            (None, 8, 32, 32, 6  65920       ['input_5[0][0]']
#                                 4)
#
#  batch_normalization_98 (BatchN  (None, 8, 32, 32, 6  256        ['conv3d_106[0][0]']
#  ormalization)                  4)
#
#  activation_98 (Activation)     (None, 8, 32, 32, 6  0           ['batch_normalization_98[0][0]']
#                                 4)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 4, 16, 16, 6  0          ['activation_98[0][0]']
#                                 4)
#
#  conv3d_107 (Conv3D)            (None, 4, 16, 16, 6  4160        ['max_pooling3d_2[0][0]']
#                                 4)
#
#  batch_normalization_99 (BatchN  (None, 4, 16, 16, 6  256        ['conv3d_107[0][0]']
#  ormalization)                  4)
#
#  activation_99 (Activation)     (None, 4, 16, 16, 6  0           ['batch_normalization_99[0][0]']
#                                 4)
#
#  conv3d_108 (Conv3D)            (None, 4, 16, 16, 6  110656      ['activation_99[0][0]']
#                                 4)
#
#  batch_normalization_100 (Batch  (None, 4, 16, 16, 6  256        ['conv3d_108[0][0]']
#  Normalization)                 4)
#
#  activation_100 (Activation)    (None, 4, 16, 16, 6  0           ['batch_normalization_100[0][0]']
#                                 4)
#
#  conv3d_110 (Conv3D)            (None, 4, 16, 16, 2  16640       ['max_pooling3d_2[0][0]']
#                                 56)
#
#  conv3d_109 (Conv3D)            (None, 4, 16, 16, 2  16640       ['activation_100[0][0]']
#                                 56)
#
#  add_32 (Add)                   (None, 4, 16, 16, 2  0           ['conv3d_110[0][0]',
#                                 56)                               'conv3d_109[0][0]']
#
#  batch_normalization_101 (Batch  (None, 4, 16, 16, 2  1024       ['add_32[0][0]']
#  Normalization)                 56)
#
#  activation_101 (Activation)    (None, 4, 16, 16, 2  0           ['batch_normalization_101[0][0]']
#                                 56)
#
#  conv3d_111 (Conv3D)            (None, 4, 16, 16, 6  16448       ['activation_101[0][0]']
#                                 4)
#
#  batch_normalization_102 (Batch  (None, 4, 16, 16, 6  256        ['conv3d_111[0][0]']
#  Normalization)                 4)
#
#  activation_102 (Activation)    (None, 4, 16, 16, 6  0           ['batch_normalization_102[0][0]']
#                                 4)
#
#  conv3d_112 (Conv3D)            (None, 4, 16, 16, 6  110656      ['activation_102[0][0]']
#                                 4)
#
#  batch_normalization_103 (Batch  (None, 4, 16, 16, 6  256        ['conv3d_112[0][0]']
#  Normalization)                 4)
#
#  activation_103 (Activation)    (None, 4, 16, 16, 6  0           ['batch_normalization_103[0][0]']
#                                 4)
#
#  conv3d_113 (Conv3D)            (None, 4, 16, 16, 2  16640       ['activation_103[0][0]']
#                                 56)
#
#  add_33 (Add)                   (None, 4, 16, 16, 2  0           ['add_32[0][0]',
#                                 56)                               'conv3d_113[0][0]']
#
#  batch_normalization_104 (Batch  (None, 4, 16, 16, 2  1024       ['add_33[0][0]']
#  Normalization)                 56)
#
#  activation_104 (Activation)    (None, 4, 16, 16, 2  0           ['batch_normalization_104[0][0]']
#                                 56)
#
#  conv3d_114 (Conv3D)            (None, 4, 16, 16, 6  16448       ['activation_104[0][0]']
#                                 4)
#
#  batch_normalization_105 (Batch  (None, 4, 16, 16, 6  256        ['conv3d_114[0][0]']
#  Normalization)                 4)
#
#  activation_105 (Activation)    (None, 4, 16, 16, 6  0           ['batch_normalization_105[0][0]']
#                                 4)
#
#  conv3d_115 (Conv3D)            (None, 4, 16, 16, 6  110656      ['activation_105[0][0]']
#                                 4)
#
#  batch_normalization_106 (Batch  (None, 4, 16, 16, 6  256        ['conv3d_115[0][0]']
#  Normalization)                 4)
#
#  activation_106 (Activation)    (None, 4, 16, 16, 6  0           ['batch_normalization_106[0][0]']
#                                 4)
#
#  conv3d_116 (Conv3D)            (None, 4, 16, 16, 2  16640       ['activation_106[0][0]']
#                                 56)
#
#  add_34 (Add)                   (None, 4, 16, 16, 2  0           ['add_33[0][0]',
#                                 56)                               'conv3d_116[0][0]']
#
#  batch_normalization_107 (Batch  (None, 4, 16, 16, 2  1024       ['add_34[0][0]']
#  Normalization)                 56)
#
#  activation_107 (Activation)    (None, 4, 16, 16, 2  0           ['batch_normalization_107[0][0]']
#                                 56)
#
#  conv3d_117 (Conv3D)            (None, 2, 8, 8, 128  32896       ['activation_107[0][0]']
#                                 )
#
#  batch_normalization_108 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_117[0][0]']
#  Normalization)                 )
#
#  activation_108 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_108[0][0]']
#                                 )
#
#  conv3d_118 (Conv3D)            (None, 2, 8, 8, 128  442496      ['activation_108[0][0]']
#                                 )
#
#  batch_normalization_109 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_118[0][0]']
#  Normalization)                 )
#
#  activation_109 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_109[0][0]']
#                                 )
#
#  conv3d_120 (Conv3D)            (None, 2, 8, 8, 512  131584      ['add_34[0][0]']
#                                 )
#
#  conv3d_119 (Conv3D)            (None, 2, 8, 8, 512  66048       ['activation_109[0][0]']
#                                 )
#
#  add_35 (Add)                   (None, 2, 8, 8, 512  0           ['conv3d_120[0][0]',
#                                 )                                 'conv3d_119[0][0]']
#
#  batch_normalization_110 (Batch  (None, 2, 8, 8, 512  2048       ['add_35[0][0]']
#  Normalization)                 )
#
#  activation_110 (Activation)    (None, 2, 8, 8, 512  0           ['batch_normalization_110[0][0]']
#                                 )
#
#  conv3d_121 (Conv3D)            (None, 2, 8, 8, 128  65664       ['activation_110[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_121[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  conv3d_122 (Conv3D)            (None, 2, 8, 8, 128  442496      ['activation_111[0][0]']
#                                 )
#
#  batch_normalization_112 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_122[0][0]']
#  Normalization)                 )
#
#  activation_112 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_112[0][0]']
#                                 )
#
#  conv3d_123 (Conv3D)            (None, 2, 8, 8, 512  66048       ['activation_112[0][0]']
#                                 )
#
#  add_36 (Add)                   (None, 2, 8, 8, 512  0           ['add_35[0][0]',
#                                 )                                 'conv3d_123[0][0]']
#
#  batch_normalization_113 (Batch  (None, 2, 8, 8, 512  2048       ['add_36[0][0]']
#  Normalization)                 )
#
#  activation_113 (Activation)    (None, 2, 8, 8, 512  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  conv3d_124 (Conv3D)            (None, 2, 8, 8, 128  65664       ['activation_113[0][0]']
#                                 )
#
#  batch_normalization_114 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_124[0][0]']
#  Normalization)                 )
#
#  activation_114 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_114[0][0]']
#                                 )
#
#  conv3d_125 (Conv3D)            (None, 2, 8, 8, 128  442496      ['activation_114[0][0]']
#                                 )
#
#  batch_normalization_115 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_125[0][0]']
#  Normalization)                 )
#
#  activation_115 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_115[0][0]']
#                                 )
#
#  conv3d_126 (Conv3D)            (None, 2, 8, 8, 512  66048       ['activation_115[0][0]']
#                                 )
#
#  add_37 (Add)                   (None, 2, 8, 8, 512  0           ['add_36[0][0]',
#                                 )                                 'conv3d_126[0][0]']
#
#  batch_normalization_116 (Batch  (None, 2, 8, 8, 512  2048       ['add_37[0][0]']
#  Normalization)                 )
#
#  activation_116 (Activation)    (None, 2, 8, 8, 512  0           ['batch_normalization_116[0][0]']
#                                 )
#
#  conv3d_127 (Conv3D)            (None, 2, 8, 8, 128  65664       ['activation_116[0][0]']
#                                 )
#
#  batch_normalization_117 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_127[0][0]']
#  Normalization)                 )
#
#  activation_117 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_117[0][0]']
#                                 )
#
#  conv3d_128 (Conv3D)            (None, 2, 8, 8, 128  442496      ['activation_117[0][0]']
#                                 )
#
#  batch_normalization_118 (Batch  (None, 2, 8, 8, 128  512        ['conv3d_128[0][0]']
#  Normalization)                 )
#
#  activation_118 (Activation)    (None, 2, 8, 8, 128  0           ['batch_normalization_118[0][0]']
#                                 )
#
#  conv3d_129 (Conv3D)            (None, 2, 8, 8, 512  66048       ['activation_118[0][0]']
#                                 )
#
#  add_38 (Add)                   (None, 2, 8, 8, 512  0           ['add_37[0][0]',
#                                 )                                 'conv3d_129[0][0]']
#
#  batch_normalization_119 (Batch  (None, 2, 8, 8, 512  2048       ['add_38[0][0]']
#  Normalization)                 )
#
#  activation_119 (Activation)    (None, 2, 8, 8, 512  0           ['batch_normalization_119[0][0]']
#                                 )
#
#  conv3d_130 (Conv3D)            (None, 1, 4, 4, 256  131328      ['activation_119[0][0]']
#                                 )
#
#  batch_normalization_120 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_130[0][0]']
#  Normalization)                 )
#
#  activation_120 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_120[0][0]']
#                                 )
#
#  conv3d_131 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_120[0][0]']
#                                 )
#
#  batch_normalization_121 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_131[0][0]']
#  Normalization)                 )
#
#  activation_121 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_121[0][0]']
#                                 )
#
#  conv3d_133 (Conv3D)            (None, 1, 4, 4, 102  525312      ['add_38[0][0]']
#                                 4)
#
#  conv3d_132 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_121[0][0]']
#                                 4)
#
#  add_39 (Add)                   (None, 1, 4, 4, 102  0           ['conv3d_133[0][0]',
#                                 4)                                'conv3d_132[0][0]']
#
#  batch_normalization_122 (Batch  (None, 1, 4, 4, 102  4096       ['add_39[0][0]']
#  Normalization)                 4)
#
#  activation_122 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_122[0][0]']
#                                 4)
#
#  conv3d_134 (Conv3D)            (None, 1, 4, 4, 256  262400      ['activation_122[0][0]']
#                                 )
#
#  batch_normalization_123 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_134[0][0]']
#  Normalization)                 )
#
#  activation_123 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_123[0][0]']
#                                 )
#
#  conv3d_135 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_123[0][0]']
#                                 )
#
#  batch_normalization_124 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_135[0][0]']
#  Normalization)                 )
#
#  activation_124 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_124[0][0]']
#                                 )
#
#  conv3d_136 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_124[0][0]']
#                                 4)
#
#  add_40 (Add)                   (None, 1, 4, 4, 102  0           ['add_39[0][0]',
#                                 4)                                'conv3d_136[0][0]']
#
#  batch_normalization_125 (Batch  (None, 1, 4, 4, 102  4096       ['add_40[0][0]']
#  Normalization)                 4)
#
#  activation_125 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_125[0][0]']
#                                 4)
#
#  conv3d_137 (Conv3D)            (None, 1, 4, 4, 256  262400      ['activation_125[0][0]']
#                                 )
#
#  batch_normalization_126 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_137[0][0]']
#  Normalization)                 )
#
#  activation_126 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_126[0][0]']
#                                 )
#
#  conv3d_138 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_126[0][0]']
#                                 )
#
#  batch_normalization_127 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_138[0][0]']
#  Normalization)                 )
#
#  activation_127 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_127[0][0]']
#                                 )
#
#  conv3d_139 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_127[0][0]']
#                                 4)
#
#  add_41 (Add)                   (None, 1, 4, 4, 102  0           ['add_40[0][0]',
#                                 4)                                'conv3d_139[0][0]']
#
#  batch_normalization_128 (Batch  (None, 1, 4, 4, 102  4096       ['add_41[0][0]']
#  Normalization)                 4)
#
#  activation_128 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_128[0][0]']
#                                 4)
#
#  conv3d_140 (Conv3D)            (None, 1, 4, 4, 256  262400      ['activation_128[0][0]']
#                                 )
#
#  batch_normalization_129 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_140[0][0]']
#  Normalization)                 )
#
#  activation_129 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_129[0][0]']
#                                 )
#
#  conv3d_141 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_129[0][0]']
#                                 )
#
#  batch_normalization_130 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_141[0][0]']
#  Normalization)                 )
#
#  activation_130 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_130[0][0]']
#                                 )
#
#  conv3d_142 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_130[0][0]']
#                                 4)
#
#  add_42 (Add)                   (None, 1, 4, 4, 102  0           ['add_41[0][0]',
#                                 4)                                'conv3d_142[0][0]']
#
#  batch_normalization_131 (Batch  (None, 1, 4, 4, 102  4096       ['add_42[0][0]']
#  Normalization)                 4)
#
#  activation_131 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_131[0][0]']
#                                 4)
#
#  conv3d_143 (Conv3D)            (None, 1, 4, 4, 256  262400      ['activation_131[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_143[0][0]']
#  Normalization)                 )
#
#  activation_132 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  conv3d_144 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_132[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_144[0][0]']
#  Normalization)                 )
#
#  activation_133 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  conv3d_145 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_133[0][0]']
#                                 4)
#
#  add_43 (Add)                   (None, 1, 4, 4, 102  0           ['add_42[0][0]',
#                                 4)                                'conv3d_145[0][0]']
#
#  batch_normalization_134 (Batch  (None, 1, 4, 4, 102  4096       ['add_43[0][0]']
#  Normalization)                 4)
#
#  activation_134 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_134[0][0]']
#                                 4)
#
#  conv3d_146 (Conv3D)            (None, 1, 4, 4, 256  262400      ['activation_134[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_146[0][0]']
#  Normalization)                 )
#
#  activation_135 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  conv3d_147 (Conv3D)            (None, 1, 4, 4, 256  1769728     ['activation_135[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 1, 4, 4, 256  1024       ['conv3d_147[0][0]']
#  Normalization)                 )
#
#  activation_136 (Activation)    (None, 1, 4, 4, 256  0           ['batch_normalization_136[0][0]']
#                                 )
#
#  conv3d_148 (Conv3D)            (None, 1, 4, 4, 102  263168      ['activation_136[0][0]']
#                                 4)
#
#  add_44 (Add)                   (None, 1, 4, 4, 102  0           ['add_43[0][0]',
#                                 4)                                'conv3d_148[0][0]']
#
#  batch_normalization_137 (Batch  (None, 1, 4, 4, 102  4096       ['add_44[0][0]']
#  Normalization)                 4)
#
#  activation_137 (Activation)    (None, 1, 4, 4, 102  0           ['batch_normalization_137[0][0]']
#                                 4)
#
#  conv3d_149 (Conv3D)            (None, 1, 2, 2, 512  524800      ['activation_137[0][0]']
#                                 )
#
#  batch_normalization_138 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_149[0][0]']
#  Normalization)                 )
#
#  activation_138 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  conv3d_150 (Conv3D)            (None, 1, 2, 2, 512  7078400     ['activation_138[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_150[0][0]']
#  Normalization)                 )
#
#  activation_139 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_139[0][0]']
#                                 )
#
#  conv3d_152 (Conv3D)            (None, 1, 2, 2, 204  2099200     ['add_44[0][0]']
#                                 8)
#
#  conv3d_151 (Conv3D)            (None, 1, 2, 2, 204  1050624     ['activation_139[0][0]']
#                                 8)
#
#  add_45 (Add)                   (None, 1, 2, 2, 204  0           ['conv3d_152[0][0]',
#                                 8)                                'conv3d_151[0][0]']
#
#  batch_normalization_140 (Batch  (None, 1, 2, 2, 204  8192       ['add_45[0][0]']
#  Normalization)                 8)
#
#  activation_140 (Activation)    (None, 1, 2, 2, 204  0           ['batch_normalization_140[0][0]']
#                                 8)
#
#  conv3d_153 (Conv3D)            (None, 1, 2, 2, 512  1049088     ['activation_140[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_153[0][0]']
#  Normalization)                 )
#
#  activation_141 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_141[0][0]']
#                                 )
#
#  conv3d_154 (Conv3D)            (None, 1, 2, 2, 512  7078400     ['activation_141[0][0]']
#                                 )
#
#  batch_normalization_142 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_154[0][0]']
#  Normalization)                 )
#
#  activation_142 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_142[0][0]']
#                                 )
#
#  conv3d_155 (Conv3D)            (None, 1, 2, 2, 204  1050624     ['activation_142[0][0]']
#                                 8)
#
#  add_46 (Add)                   (None, 1, 2, 2, 204  0           ['add_45[0][0]',
#                                 8)                                'conv3d_155[0][0]']
#
#  batch_normalization_143 (Batch  (None, 1, 2, 2, 204  8192       ['add_46[0][0]']
#  Normalization)                 8)
#
#  activation_143 (Activation)    (None, 1, 2, 2, 204  0           ['batch_normalization_143[0][0]']
#                                 8)
#
#  conv3d_156 (Conv3D)            (None, 1, 2, 2, 512  1049088     ['activation_143[0][0]']
#                                 )
#
#  batch_normalization_144 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_156[0][0]']
#  Normalization)                 )
#
#  activation_144 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_144[0][0]']
#                                 )
#
#  conv3d_157 (Conv3D)            (None, 1, 2, 2, 512  7078400     ['activation_144[0][0]']
#                                 )
#
#  batch_normalization_145 (Batch  (None, 1, 2, 2, 512  2048       ['conv3d_157[0][0]']
#  Normalization)                 )
#
#  activation_145 (Activation)    (None, 1, 2, 2, 512  0           ['batch_normalization_145[0][0]']
#                                 )
#
#  conv3d_158 (Conv3D)            (None, 1, 2, 2, 204  1050624     ['activation_145[0][0]']
#                                 8)
#
#  add_47 (Add)                   (None, 1, 2, 2, 204  0           ['add_46[0][0]',
#                                 8)                                'conv3d_158[0][0]']
#
#  batch_normalization_146 (Batch  (None, 1, 2, 2, 204  8192       ['add_47[0][0]']
#  Normalization)                 8)
#
#  activation_146 (Activation)    (None, 1, 2, 2, 204  0           ['batch_normalization_146[0][0]']
#                                 8)
#
#  average_pooling3d_2 (AveragePo  (None, 1, 1, 1, 204  0          ['activation_146[0][0]']
#  oling3D)                       8)
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['average_pooling3d_2[0][0]']
#
#  dense_2 (Dense)                (None, 2)            4098        ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 46,267,394
# Trainable params: 46,221,954
# Non-trainable params: 45,440
# __________________________________________________________________________________________________
# Epoch 1/18
# 14/14 [==============================] - 115s 7s/step - loss: 5.9908 - accuracy: 0.7550 - val_loss: 7.4731 - val_accuracy: 0.7463
# Epoch 2/18
# 14/14 [==============================] - 105s 7s/step - loss: 5.8950 - accuracy: 0.7600 - val_loss: 6.1023 - val_accuracy: 0.7612
# Epoch 3/18
# 14/14 [==============================] - 104s 7s/step - loss: 5.8190 - accuracy: 0.7650 - val_loss: 6.1080 - val_accuracy: 0.5970
# Epoch 4/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.7575 - accuracy: 0.8000 - val_loss: 5.9728 - val_accuracy: 0.7015
# Epoch 5/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.7244 - accuracy: 0.8450 - val_loss: 5.9598 - val_accuracy: 0.6866
# Epoch 6/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.6546 - accuracy: 0.9200 - val_loss: 5.9270 - val_accuracy: 0.6866
# Epoch 7/18
# 14/14 [==============================] - 101s 7s/step - loss: 5.6288 - accuracy: 0.9000 - val_loss: 5.9392 - val_accuracy: 0.6567
# Epoch 8/18
# 14/14 [==============================] - 105s 8s/step - loss: 5.5970 - accuracy: 0.9200 - val_loss: 5.8748 - val_accuracy: 0.7313
# Epoch 9/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.5465 - accuracy: 0.9800 - val_loss: 5.8645 - val_accuracy: 0.6866
# Epoch 10/18
# 14/14 [==============================] - 103s 7s/step - loss: 5.5249 - accuracy: 0.9650 - val_loss: 5.8744 - val_accuracy: 0.7015
# Epoch 11/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.4768 - accuracy: 0.9900 - val_loss: 5.8566 - val_accuracy: 0.7015
# Epoch 12/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.4708 - accuracy: 0.9700 - val_loss: 5.8556 - val_accuracy: 0.7015
# Epoch 13/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.4296 - accuracy: 0.9900 - val_loss: 5.8451 - val_accuracy: 0.7164
# Epoch 14/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.4273 - accuracy: 0.9800 - val_loss: 5.8403 - val_accuracy: 0.7164
# Epoch 15/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.3888 - accuracy: 0.9950 - val_loss: 5.8369 - val_accuracy: 0.7164
# Epoch 16/18
# 14/14 [==============================] - 102s 7s/step - loss: 5.3784 - accuracy: 0.9850 - val_loss: 5.8300 - val_accuracy: 0.7164
# Epoch 17/18
# 14/14 [==============================] - 104s 7s/step - loss: 5.3399 - accuracy: 0.9900 - val_loss: 5.8411 - val_accuracy: 0.7164
# Epoch 18/18
# 14/14 [==============================] - 101s 7s/step - loss: 5.3240 - accuracy: 0.9950 - val_loss: 5.8438 - val_accuracy: 0.7313
# 0.9169444508022733
# 0.7039801014794244
# 5.576347139146593
# 5.991408401065403

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='TrainingAccuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.savefig(r'val2.png' , dpi = 300)
plt.show()

# %%
pred = model.predict(x_test)
pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test , axis =1)
confusion = confusion_matrix(y_test , pred , labels=[0 , 1])
print(confusion)
# Out:
# [[ 1 22]
#  [ 1 65]]

# %%
plt.imshow(confusion_matrix(y_test , pred) , cmap = 'coolwarm' , interpolation  = 'None')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.xticks(range(2))
plt.yticks(range(2))
plt.ylabel('True Label')
# Out:
# Text(0, 0.5, 'True Label')

# %%
from sklearn.metrics import classification_report
#y_test = np.argmax(y_test , axis =1)
#Y_TEST = np.argmax(y_valid, axis=1)
#y_pred = model.predict(x_test)

print(classification_report(y_test, pred))
#print(confusion_matrix(y_test , y_pred , labels=[0 , 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.04      0.08        23
#            1       0.75      0.98      0.85        66
#
#     accuracy                           0.74        89
#    macro avg       0.62      0.51      0.46        89
# weighted avg       0.68      0.74      0.65        89
